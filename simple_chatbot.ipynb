# %% [markdown]
# <a href="https://colab.research.google.com/github/keyonai/RAG-chatbot-experiments/blob/main/simple_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q llama-index-llms-gemini llama-index google-generativeai
import os

GOOGLE_API_KEY = ""  # Replace with your actual API key
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

if GOOGLE_API_KEY == "YOUR_API_KEY_HERE":
    print("WARNING: Please replace YOUR_API_KEY_HERE with your actual API key!")
    print("Get one free at: https://aistudio.google.com/app/apikey")


# Import necessary modules
from llama_index.llms.gemini import Gemini
from llama_index.core.llms import ChatMessage

# Initialize the Gemini model
llm = Gemini(
    model="models/gemini-2.5-flash",  # Can also use "models/gemini-pro" if preferred
)

def simple_chatbot():
    """
    A simple interactive chatbot using Gemini with LlamaIndex.
    """
    print("🦙 Simple Gemini Chatbot 🦙")
    print("Type 'exit' to end the conversation")
    print("-" * 50)

    # Initialize chat history
    messages = []

    while True:
        # Get user input
        user_input = input("\nYou: ")

        # Check for exit command
        if user_input.lower() in ["exit", "quit", "bye"]:
            print("\nChatbot: Goodbye! Have a great day!")
            break

        # Add user message to history
        messages.append(ChatMessage(role="user", content=user_input))

        try:
            # Get response from Gemini
            response = llm.chat(messages)

            # Print the response
            print(f"\nChatbot: {response.message.content}")

            # Add assistant response to history
            messages.append(ChatMessage(role="assistant", content=response.message.content))

        except Exception as e:
            print(f"\nError: {e}")
            print("Please try again or check your API key")

# Run the chatbot
if __name__ == "__main__":
    simple_chatbot()
# Out:
# /tmp/ipykernel_12854/2643702080.py:17: DeprecationWarning: Call to deprecated class Gemini. (Should use `llama-index-llms-google-genai` instead, using Google's latest unified SDK. See: https://docs.llamaindex.ai/en/stable/examples/llm/google_genai/This package will no longer be supported after version 0.6.2) -- Deprecated since version 0.6.2.
#   llm = Gemini(
# 🦙 Simple Gemini Chatbot 🦙
# Type 'exit' to end the conversation
# --------------------------------------------------
#
# You: hey
#
# Chatbot: Hey there! How can I help you today?
#
# You: what are you?
#
# Chatbot: I am a large language model, trained by Google.
#
# I'm designed to assist with a wide range of tasks, like answering questions, generating text, summarizing information, translating languages, and much more. I don't have personal feelings, consciousness, or a physical body.
#
# You: ok thanks bye
#
# Chatbot: You're welcome! Have a great day!
#
# You: exit
#
# Chatbot: Goodbye! Have a great day!
